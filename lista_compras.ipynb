# %% [markdown]
# Daisy module $ 1249.00 : https://shop.openbci.com/products/daisy-module?_pos=2&_psq=daisy&_ss=e&_v=1.0
#
# <img src="imagens/daisy.png" width="400">
#
# ---

# %% [markdown]
#  * Dry EEG Comb Electrodes  $44.99 : https://shop.openbci.com/products/5-mm-spike-electrode-pack-of-30?_pos=8&_fid=fb8e44fc0&_ss=c
#  - Há uma especificação de vida útil do eletrodo: 10 usos
#
#  - <img src="imagens/{03AAB784-AA77-4610-BCB7-F251F8202F87}.png" width="400">
#
# ---

# %% [markdown]
#  <!-- * Ten20 conductive paste 	$19.99 : https://shop.openbci.com/products/ten20-conductive-paste-8oz-jar -->
#
# 8 eletrodos $399.99 ou 16 eletrodos $499.99 : https://shop.openbci.com/products/ultracortex-mark-iv?variant=23280716419
